# %%
import pandas as pd
import numpy as np
null_values = pd.Series([1,np.NaN,2,np.NaN,3,4,np.NaN,6])
print(null_values)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    3.0
# 5    4.0
# 6    NaN
# 7    6.0
# dtype: float64

# %%
null_values.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
null_values.notna()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
null_values.fillna(method = "ffill")
# Out:
# 0    1.0
# 1    1.0
# 2    2.0
# 3    2.0
# 4    3.0
# 5    4.0
# 6    4.0
# 7    6.0
# dtype: float64

# %%
null_values.fillna(method = "bfill")
# Out:
# 0    1.0
# 1    2.0
# 2    2.0
# 3    3.0
# 4    3.0
# 5    4.0
# 6    6.0
# 7    6.0
# dtype: float64

# %%
null_values.fillna("Empty")
# Out:
# 0      1.0
# 1    Empty
# 2      2.0
# 3    Empty
# 4      3.0
# 5      4.0
# 6    Empty
# 7      6.0
# dtype: object

# %%
null_values.fillna(np.mean(null_values))
# Out:
# 0    1.0
# 1    3.2
# 2    2.0
# 3    3.2
# 4    3.0
# 5    4.0
# 6    3.2
# 7    6.0
# dtype: float64

# %%
null_values.interpolate()
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    2.5
# 4    3.0
# 5    4.0
# 6    5.0
# 7    6.0
# dtype: float64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2be4fc47-c92a-4aec-aa20-21ace7a9229b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2be4fc47-c92a-4aec-aa20-21ace7a9229b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['StudentsPerformance.csv']))
print(df)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      NaN        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3      NaN        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6      NaN        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.isna()
df.notna();
df.isna().sum()
df.fillna({"writing score" : df["writing score"].mean()})
df.fillna({"reading score" : df["reading score"].median()})
df.fillna(method="bfill")
df.interpolate
# Out:
# <bound method DataFrame.interpolate of     gender race/ethnicity parental level of education         lunch  \
# 0      NaN        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3      NaN        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6      NaN        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# ...

# %%
df.fillna({"writing score" : df["writing score"].mean()})
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      NaN        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3      NaN        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6      NaN        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.fillna({"reading score" : df["reading score"].median()})
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      NaN        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3      NaN        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6      NaN        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.fillna({"reading score" : df["reading score"].median()},inplace=True)
print(df)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      NaN        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3      NaN        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6      NaN        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.fillna({"writing score" : df["writing score"].mean()},inplace=True)

# %%
print(df)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      NaN        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3      NaN        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6      NaN        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df["gender"].fillna("Male", inplace = True)

# %%
print(df)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     Male        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     Male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6     Male        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.replace('male','female')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     Male        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     Male        group A          associate's degree  free/reduced
# 4   female        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6     Male        group B                some college      standard
# 7   female        group B                some college  free/reduced
# 8   female        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10  female        group C          associate's degree      standard
# 11  female        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...
